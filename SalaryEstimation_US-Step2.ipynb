# %%
from google.colab import files

# %%
import pandas as pd

# %%
#New file contains Salary Estimate without PerHour and -1
df = pd.read_csv('my_dataframe.csv')
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                              Senior Data Scientist
# 1              1                  Data Scientist, Product Analytics
# 2              2                               Data Science Manager
# 3              3                                       Data Analyst
# 4              4                             Director, Data Science
# ...          ...                                                ...
# 5495        5881                              Information Scientist
# 5496        5882              Supervisory Research Health Scientist
# 5497        5883                  Senior SAS Programmer (Scientist)
# 5498        5886  Senior Data Analyst - Product Analytics (open ...
# 5499        5887                Manufacturing Data Analyst Engineer
#
#                     Salary Estimate  Rating  \
# 0       111 - 181  (Glassdoor est.)     3.5
# 1       111 - 181  (Glassdoor est.)     4.5
# 2       111 - 181  (Glassdoor est.)    -1.0
# 3       111 - 181  (Glassdoor est.)     3.4
# 4       111 - 181  (Glassdoor est.)     3.4
# ...                             ...     ...
# 5495    38  -  64  (Glassdoor est.)     3.2
# 5496    47  -  89  (Glassdoor est.)     4.2
# 5497   66  -  113  (Glassdoor est.)     4.0
# 5498   67  -  111  (Glassdoor est.)     4.0
# 5499    42  -  76  (Glassdoor est.)     3.6
#
#                                          Company Name        Location  \
# 0                                         Hopper\n3.5    New York, NY
# 1                                        Noom US\n4.5    New York, NY
# 2                                            Decode_M    New York, NY
# 3                               Sapphire Digital\n3.4   Lyndhurst, NJ
# 4                     United Entertainment Group\n3.4    New York, NY
# ...                                               ...             ...
# 5495                                         CAS\n3.2    Columbus, OH
# 5496  Centers for Disease Control and Prevention\n4.2  Cincinnati, OH
# 5497                                     Certara\n4.0  Cincinnati, OH
# 5498                                   New Relic\n4.0  Cincinnati, OH
# 5499                                 Hose Master\n3.6      Euclid, OH
#
#                         Size Founded               Type of ownership  \
# 0      501 to 1000 employees    2007               Company - Private
# 1     1001 to 5000 employees    2008               Company - Private
# 2          1 to 50 employees      -1                         Unknown
# 3       201 to 500 employees    2019               Company - Private
# 4        51 to 200 employees    2007               Company - Private
# ...                      ...     ...                             ...
# 5495  1001 to 5000 Employees    1907  Subsidiary or Business Segment
# 5496        10000+ Employees    1946                      Government
# 5497   501 to 1000 Employees    2008                Company - Public
# 5498  1001 to 5000 Employees    2008                Company - Public
# 5499    201 to 500 Employees    1982               Company - Private
#
#                                      Industry                     Sector  \
# 0                             Travel Agencies           Travel & Tourism
# 1                   Health, Beauty, & Fitness          Consumer Services
# 2                                          -1                         -1
# 3                                    Internet     Information Technology
# 4                     Advertising & Marketing          Business Services
# ...                                       ...                        ...
# 5495  Enterprise Software & Network Solutions     Information Technology
# 5496                         Federal Agencies                 Government
# 5497                Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 5498             Computer Hardware & Software     Information Technology
# 5499    Electrical & Electronic Manufacturing              Manufacturing
#
#                          Revenue
# 0       Unknown / Non-Applicable
# 1       Unknown / Non-Applicable
# 2       Unknown / Non-Applicable
# 3       Unknown / Non-Applicable
# 4       Unknown / Non-Applicable
# ...                          ...
# 5495  $100 to $500 million (USD)
# 5496    Unknown / Non-Applicable
# 5497    Unknown / Non-Applicable
# 5498  $100 to $500 million (USD)
# 5499    Unknown / Non-Applicable
#
# [5500 rows x 12 columns]

# %%
def splitter(a):
  a = a.split()
  return(a)

# %%
df['Salary Estimate'] = df['Salary Estimate'].apply(splitter)

# %%
def min_finder (a):
  a = a[0]
  return(a)
def max_finder(a):
  a = a[2]
  return(a)

# %%
df['Min_salary'] = df['Salary Estimate'].apply(min_finder)
df['Max_salary'] = df['Salary Estimate'].apply(max_finder)

# %%
df['Min_salary'] = df['Min_salary'].astype(int)
df['Max_salary'] = df['Max_salary'].astype(int)

# %%
def state(a):
  a= a.split()
  a = a[-1]
  return(a)

# %%
 df['State'] = df['Location'].apply(state)

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                              Senior Data Scientist
# 1              1                  Data Scientist, Product Analytics
# 2              2                               Data Science Manager
# 3              3                                       Data Analyst
# 4              4                             Director, Data Science
# ...          ...                                                ...
# 5495        5881                              Information Scientist
# 5496        5882              Supervisory Research Health Scientist
# 5497        5883                  Senior SAS Programmer (Scientist)
# 5498        5886  Senior Data Analyst - Product Analytics (open ...
# 5499        5887                Manufacturing Data Analyst Engineer
#
#                        Salary Estimate  Rating  \
# 0     [111, -, 181, (Glassdoor, est.)]     3.5
# 1     [111, -, 181, (Glassdoor, est.)]     4.5
# 2     [111, -, 181, (Glassdoor, est.)]    -1.0
# 3     [111, -, 181, (Glassdoor, est.)]     3.4
# 4     [111, -, 181, (Glassdoor, est.)]     3.4
# ...                                ...     ...
# 5495    [38, -, 64, (Glassdoor, est.)]     3.2
# 5496    [47, -, 89, (Glassdoor, est.)]     4.2
# 5497   [66, -, 113, (Glassdoor, est.)]     4.0
# 5498   [67, -, 111, (Glassdoor, est.)]     4.0
# 5499    [42, -, 76, (Glassdoor, est.)]     3.6
#
#                                          Company Name        Location  \
# 0                                         Hopper\n3.5    New York, NY
# 1                                        Noom US\n4.5    New York, NY
# 2                                            Decode_M    New York, NY
# 3                               Sapphire Digital\n3.4   Lyndhurst, NJ
# 4                     United Entertainment Group\n3.4    New York, NY
# ...                                               ...             ...
# 5495                                         CAS\n3.2    Columbus, OH
# 5496  Centers for Disease Control and Prevention\n4.2  Cincinnati, OH
# 5497                                     Certara\n4.0  Cincinnati, OH
# 5498                                   New Relic\n4.0  Cincinnati, OH
# 5499                                 Hose Master\n3.6      Euclid, OH
#
#                         Size Founded               Type of ownership  \
# 0      501 to 1000 employees    2007               Company - Private
# 1     1001 to 5000 employees    2008               Company - Private
# 2          1 to 50 employees      -1                         Unknown
# 3       201 to 500 employees    2019               Company - Private
# 4        51 to 200 employees    2007               Company - Private
# ...                      ...     ...                             ...
# 5495  1001 to 5000 Employees    1907  Subsidiary or Business Segment
# 5496        10000+ Employees    1946                      Government
# 5497   501 to 1000 Employees    2008                Company - Public
# 5498  1001 to 5000 Employees    2008                Company - Public
# 5499    201 to 500 Employees    1982               Company - Private
#
#                                      Industry                     Sector  \
# 0                             Travel Agencies           Travel & Tourism
# 1                   Health, Beauty, & Fitness          Consumer Services
# 2                                          -1                         -1
# 3                                    Internet     Information Technology
# 4                     Advertising & Marketing          Business Services
# ...                                       ...                        ...
# 5495  Enterprise Software & Network Solutions     Information Technology
# 5496                         Federal Agencies                 Government
# 5497                Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 5498             Computer Hardware & Software     Information Technology
# 5499    Electrical & Electronic Manufacturing              Manufacturing
#
#                          Revenue  Min_salary  Max_salary State
# 0       Unknown / Non-Applicable         111         181    NY
# 1       Unknown / Non-Applicable         111         181    NY
# 2       Unknown / Non-Applicable         111         181    NY
# 3       Unknown / Non-Applicable         111         181    NJ
# 4       Unknown / Non-Applicable         111         181    NY
# ...                          ...         ...         ...   ...
# 5495  $100 to $500 million (USD)          38          64    OH
# 5496    Unknown / Non-Applicable          47          89    OH
# 5497    Unknown / Non-Applicable          66         113    OH
# 5498  $100 to $500 million (USD)          67         111    OH
# 5499    Unknown / Non-Applicable          42          76    OH
#
# [5500 rows x 15 columns]

# %%
#Remove Kingdom from state Column
df = df[df['State'] != 'Kingdom']

# %%
#Remove -1 from Rating Column
df = df[df['Rating']!= -1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4891 entries, 0 to 5499
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4891 non-null   int64
#  1   Job Title          4891 non-null   object
#  2   Salary Estimate    4891 non-null   object
#  3   Rating             4891 non-null   float64
#  4   Company Name       4891 non-null   object
#  5   Location           4891 non-null   object
#  6   Size               4891 non-null   object
#  7   Founded            4891 non-null   object
#  8   Type of ownership  4891 non-null   object
#  9   Industry           4891 non-null   object
#  10  Sector             4891 non-null   object
#  11  Revenue            4891 non-null   object
#  12  Min_salary         4891 non-null   int32
#  13  Max_salary         4891 non-null   int32
#  14  State              4891 non-null   object
# dtypes: float64(1), int32(2), int64(1), object(11)
# memory usage: 573.2+ KB
