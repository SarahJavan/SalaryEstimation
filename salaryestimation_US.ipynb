# %%
import pandas as pd

# %%
df = pd.read_csv('df.csv')

# %%
df.info()
df.head()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5526 entries, 0 to 5891
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5526 non-null   object
#  1   Salary Estimate    5526 non-null   object
#  2   Rating             5526 non-null   float64
#  3   Company Name       5526 non-null   object
#  4   Location           5526 non-null   object
#  5   Size               5526 non-null   object
#  6   Founded            5526 non-null   object
#  7   Type of ownership  5526 non-null   object
#  8   Industry           5526 non-null   object
#  9   Sector             5526 non-null   object
#  10  Revenue            5526 non-null   object
#  11  Hourly             5526 non-null   int64
#  12  Employer_provided  5526 non-null   int64
#  13  Min_salary         5526 non-null   int64
#  14  Max_salary         5526 non-null   int64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 690.8+ KB
#                                               Job Title  \
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                 Salary Estimate  Rating  \
# 5882   47 - 89 (Glassdoor est.)     4.2
# 5883  66 - 113 (Glassdoor est.)     4.0
# 5886  67 - 111 (Glassdoor est.)     4.0
# 5887   42 - 76 (Glassdoor est.)     3.6
# 5891           65 - 72 Per Hour     3.7
#
#                                          Company Name        Location  \
# 5882  Centers for Disease Control and Prevention\n4.2  Cincinnati, OH
# 5883                                     Certara\n4.0  Cincinnati, OH
# 5886                                   New Relic\n4.0  Cincinnati, OH
# 5887                                 Hose Master\n3.6      Euclid, OH
# 5891                                      Epitec\n3.7   Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# 5882        10000+ Employees    1946         Government
# 5883   501 to 1000 Employees    2008   Company - Public
# 5886  1001 to 5000 Employees    2008   Company - Public
# 5887    201 to 500 Employees    1982  Company - Private
# 5891  1001 to 5000 Employees    1978  Company - Private
#
#                                    Industry                     Sector  \
# 5882                       Federal Agencies                 Government
# 5883              Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 5886           Computer Hardware & Software     Information Technology
# 5887  Electrical & Electronic Manufacturing              Manufacturing
# 5891                 Staffing & Outsourcing          Business Services
#
#                          Revenue  Hourly  Employer_provided  Min_salary  \
# 5882    Unknown / Non-Applicable       0                  0          47
# 5883    Unknown / Non-Applicable       0                  0          66
# 5886  $100 to $500 million (USD)       0                  0          67
# 5887    Unknown / Non-Applicable       0                  0          42
# 5891  $100 to $500 million (USD)       1                  0          65
#
#       Max_salary
# 5882          89
# 5883         113
# 5886         111
# 5887          76
# 5891          72

# %%
df.head()
# Out:
#                            Job Title           Salary Estimate  Rating  \
# 0              Senior Data Scientist  111-181 (Glassdoor est.)     3.5
# 1  Data Scientist, Product Analytics  111-181 (Glassdoor est.)     4.5
# 2               Data Science Manager  111-181 (Glassdoor est.)    -1.0
# 3                       Data Analyst  111-181 (Glassdoor est.)     3.4
# 4             Director, Data Science  111-181 (Glassdoor est.)     3.4
#
#                       Company Name       Location                    Size  \
# 0                      Hopper\n3.5   New York, NY   501 to 1000 employees
# 1                     Noom US\n4.5   New York, NY  1001 to 5000 employees
# 2                         Decode_M   New York, NY       1 to 50 employees
# 3            Sapphire Digital\n3.4  Lyndhurst, NJ    201 to 500 employees
# 4  United Entertainment Group\n3.4   New York, NY     51 to 200 employees
#
#   Founded  Type of ownership                   Industry  \
# 0    2007  Company - Private            Travel Agencies
# 1    2008  Company - Private  Health, Beauty, & Fitness
# 2      -1            Unknown                         -1
# 3    2019  Company - Private                   Internet
# 4    2007  Company - Private    Advertising & Marketing
#
#                    Sector                   Revenue  Hourly  \
# 0        Travel & Tourism  Unknown / Non-Applicable       0
# 1       Consumer Services  Unknown / Non-Applicable       0
# 2                      -1  Unknown / Non-Applicable       0
# 3  Information Technology  Unknown / Non-Applicable       0
# 4       Business Services  Unknown / Non-Applicable       0
#
#    Employer_provided  Min_salary  Max_salary
# 0                  0         111         181
# 1                  0         111         181
# 2                  0         111         181
# 3                  0         111         181
# 4                  0         111         181

# %%
df.tail()
# Out:
#                                               Job Title  \
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                 Salary Estimate  Rating  \
# 5882   47 - 89 (Glassdoor est.)     4.2
# 5883  66 - 113 (Glassdoor est.)     4.0
# 5886  67 - 111 (Glassdoor est.)     4.0
# 5887   42 - 76 (Glassdoor est.)     3.6
# 5891           65 - 72 Per Hour     3.7
#
#                                          Company Name        Location  \
# 5882  Centers for Disease Control and Prevention\n4.2  Cincinnati, OH
# 5883                                     Certara\n4.0  Cincinnati, OH
# 5886                                   New Relic\n4.0  Cincinnati, OH
# 5887                                 Hose Master\n3.6      Euclid, OH
# 5891                                      Epitec\n3.7   Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# 5882        10000+ Employees    1946         Government
# 5883   501 to 1000 Employees    2008   Company - Public
# 5886  1001 to 5000 Employees    2008   Company - Public
# 5887    201 to 500 Employees    1982  Company - Private
# 5891  1001 to 5000 Employees    1978  Company - Private
#
#                                    Industry                     Sector  \
# 5882                       Federal Agencies                 Government
# 5883              Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 5886           Computer Hardware & Software     Information Technology
# 5887  Electrical & Electronic Manufacturing              Manufacturing
# 5891                 Staffing & Outsourcing          Business Services
#
#                          Revenue  Hourly  Employer_provided  Min_salary  \
# 5882    Unknown / Non-Applicable       0                  0          47
# 5883    Unknown / Non-Applicable       0                  0          66
# 5886  $100 to $500 million (USD)       0                  0          67
# 5887    Unknown / Non-Applicable       0                  0          42
# 5891  $100 to $500 million (USD)       1                  0          65
#
#       Max_salary
# 5882          89
# 5883         113
# 5886         111
# 5887          76
# 5891          72

# %%
df.get('Salary Estimate')
# Out:
# 0        111-181 (Glassdoor est.)
# 1        111-181 (Glassdoor est.)
# 2        111-181 (Glassdoor est.)
# 3        111-181 (Glassdoor est.)
# 4        111-181 (Glassdoor est.)
#                   ...
# 5882     47 - 89 (Glassdoor est.)
# 5883    66 - 113 (Glassdoor est.)
# 5886    67 - 111 (Glassdoor est.)
# 5887     42 - 76 (Glassdoor est.)
# 5891             65 - 72 Per Hour
# Name: Salary Estimate, Length: 5526, dtype: object

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
#       Rating                          Company Name       Location  \
# 0        3.5                           Hopper\n3.5   New York, NY
# 1        4.5                          Noom US\n4.5   New York, NY
# 2       -1.0                              Decode_M   New York, NY
# 3        3.4                 Sapphire Digital\n3.4  Lyndhurst, NJ
# 4        3.4       United Entertainment Group\n3.4   New York, NY
# ...      ...                                   ...            ...
# 5887     3.6                      Hose Master\n3.6     Euclid, OH
# 5888     4.9                 Bluetree Network\n4.9    Madison, WI
# 5889     4.0  Kimberly-Clark Corporation, LLC\n4.0     Neenah, WI
# 5890     4.0            AE Business Solutions\n4.0    Madison, WI
# 5891     3.7                           Epitec\n3.7  Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# 0      501 to 1000 employees    2007  Company - Private
# 1     1001 to 5000 employees    2008  Company - Private
# 2          1 to 50 employees      -1            Unknown
# 3       201 to 500 employees    2019  Company - Private
# 4        51 to 200 employees    2007  Company - Private
# ...                      ...     ...                ...
# 5887    201 to 500 Employees    1982  Company - Private
# 5888                      -1      -1                 -1
# 5889        10000+ Employees    1872   Company - Public
# 5890     51 to 200 Employees    1949  Company - Private
# 5891  1001 to 5000 Employees    1978  Company - Private
#
#                                    Industry                  Sector  \
# 0                           Travel Agencies        Travel & Tourism
# 1                 Health, Beauty, & Fitness       Consumer Services
# 2                                        -1                      -1
# 3                                  Internet  Information Technology
# 4                   Advertising & Marketing       Business Services
# ...                                     ...                     ...
# 5887  Electrical & Electronic Manufacturing           Manufacturing
# 5888                                     -1                      -1
# 5889        Consumer Products Manufacturing           Manufacturing
# 5890           Computer Hardware & Software  Information Technology
# 5891                 Staffing & Outsourcing       Business Services
#
#                          Revenue
# 0       Unknown / Non-Applicable
# 1       Unknown / Non-Applicable
# 2       Unknown / Non-Applicable
# 3       Unknown / Non-Applicable
# 4       Unknown / Non-Applicable
# ...                          ...
# 5887    Unknown / Non-Applicable
# 5888                          -1
# 5889          $10+ billion (USD)
# 5890    $25 to $50 million (USD)
# 5891  $100 to $500 million (USD)
#
# [5892 rows x 11 columns]

# %%
# returns the count of job items 
df['Job Title'].value_counts()
df['Salary Estimate'].value_counts()
# Out:
# $93K-$151K (Glassdoor est.)      62
# $113K-$180K (Glassdoor est.)     61
# $71K-$122K (Glassdoor est.)      60
# $111K-$175K (Glassdoor est.)     60
# $119K-$147K (Glassdoor est.)     44
#                                  ..
# $52K - $98K (Glassdoor est.)      1
# $65K - $133K (Glassdoor est.)     1
# $60K - $106K (Glassdoor est.)     1
# $58K - $96K (Glassdoor est.)      1
# $65 - $72 Per Hour                1
# Name: Salary Estimate, Length: 1320, dtype: int64

# %%
# Remove instances without salary estimates values
df = df[df['Salary Estimate'] != '-1']

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                     Salary Estimate  Rating  \
# 0      $111K-$181K (Glassdoor est.)     3.5
# 1      $111K-$181K (Glassdoor est.)     4.5
# 2      $111K-$181K (Glassdoor est.)    -1.0
# 3      $111K-$181K (Glassdoor est.)     3.4
# 4      $111K-$181K (Glassdoor est.)     3.4
# ...                             ...     ...
# 5882   $47K - $89K (Glassdoor est.)     4.2
# 5883  $66K - $113K (Glassdoor est.)     4.0
# 5886  $67K - $111K (Glassdoor est.)     4.0
# 5887   $42K - $76K (Glassdoor est.)     3.6
# 5891             $65 - $72 Per Hour     3.7
#
#                                          Company Name        Location  \
# 0                                         Hopper\n3.5    New York, NY
# 1                                        Noom US\n4.5    New York, NY
# 2                                            Decode_M    New York, NY
# 3                               Sapphire Digital\n3.4   Lyndhurst, NJ
# 4                     United Entertainment Group\n3.4    New York, NY
# ...                                               ...             ...
# 5882  Centers for Disease Control and Prevention\n4.2  Cincinnati, OH
# 5883                                     Certara\n4.0  Cincinnati, OH
# 5886                                   New Relic\n4.0  Cincinnati, OH
# 5887                                 Hose Master\n3.6      Euclid, OH
# 5891                                      Epitec\n3.7   Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# 0      501 to 1000 employees    2007  Company - Private
# 1     1001 to 5000 employees    2008  Company - Private
# 2          1 to 50 employees      -1            Unknown
# 3       201 to 500 employees    2019  Company - Private
# 4        51 to 200 employees    2007  Company - Private
# ...                      ...     ...                ...
# 5882        10000+ Employees    1946         Government
# 5883   501 to 1000 Employees    2008   Company - Public
# 5886  1001 to 5000 Employees    2008   Company - Public
# 5887    201 to 500 Employees    1982  Company - Private
# 5891  1001 to 5000 Employees    1978  Company - Private
#
#                                    Industry                     Sector  \
# 0                           Travel Agencies           Travel & Tourism
# 1                 Health, Beauty, & Fitness          Consumer Services
# 2                                        -1                         -1
# 3                                  Internet     Information Technology
# 4                   Advertising & Marketing          Business Services
# ...                                     ...                        ...
# 5882                       Federal Agencies                 Government
# 5883              Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 5886           Computer Hardware & Software     Information Technology
# 5887  Electrical & Electronic Manufacturing              Manufacturing
# 5891                 Staffing & Outsourcing          Business Services
#
#                          Revenue
# 0       Unknown / Non-Applicable
# 1       Unknown / Non-Applicable
# 2       Unknown / Non-Applicable
# 3       Unknown / Non-Applicable
# 4       Unknown / Non-Applicable
# ...                          ...
# 5882    Unknown / Non-Applicable
# 5883    Unknown / Non-Applicable
# 5886  $100 to $500 million (USD)
# 5887    Unknown / Non-Applicable
# 5891  $100 to $500 million (USD)
#
# [5526 rows x 11 columns]

# %%
## Remove K and $ from salary estimate column
df['Salary Estimate'] = df['Salary Estimate'].apply(lambda x: x.replace('K', '').replace('$', ''))

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# 5882   47 - 89 (Glassdoor est.)     4.2
# 5883  66 - 113 (Glassdoor est.)     4.0
# 5886  67 - 111 (Glassdoor est.)     4.0
# 5887   42 - 76 (Glassdoor est.)     3.6
# 5891           65 - 72 Per Hour     3.7
#
#                                          Company Name        Location  \
# 0                                         Hopper\n3.5    New York, NY
# 1                                        Noom US\n4.5    New York, NY
# 2                                            Decode_M    New York, NY
# 3                               Sapphire Digital\n3.4   Lyndhurst, NJ
# 4                     United Entertainment Group\n3.4    New York, NY
# ...                                               ...             ...
# 5882  Centers for Disease Control and Prevention\n4.2  Cincinnati, OH
# 5883                                     Certara\n4.0  Cincinnati, OH
# 5886                                   New Relic\n4.0  Cincinnati, OH
# 5887                                 Hose Master\n3.6      Euclid, OH
# 5891                                      Epitec\n3.7   Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# 0      501 to 1000 employees    2007  Company - Private
# 1     1001 to 5000 employees    2008  Company - Private
# 2          1 to 50 employees      -1            Unknown
# 3       201 to 500 employees    2019  Company - Private
# 4        51 to 200 employees    2007  Company - Private
# ...                      ...     ...                ...
# 5882        10000+ Employees    1946         Government
# 5883   501 to 1000 Employees    2008   Company - Public
# 5886  1001 to 5000 Employees    2008   Company - Public
# 5887    201 to 500 Employees    1982  Company - Private
# 5891  1001 to 5000 Employees    1978  Company - Private
#
#                                    Industry                     Sector  \
# 0                           Travel Agencies           Travel & Tourism
# 1                 Health, Beauty, & Fitness          Consumer Services
# 2                                        -1                         -1
# 3                                  Internet     Information Technology
# 4                   Advertising & Marketing          Business Services
# ...                                     ...                        ...
# 5882                       Federal Agencies                 Government
# 5883              Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 5886           Computer Hardware & Software     Information Technology
# 5887  Electrical & Electronic Manufacturing              Manufacturing
# 5891                 Staffing & Outsourcing          Business Services
#
#                          Revenue
# 0       Unknown / Non-Applicable
# 1       Unknown / Non-Applicable
# 2       Unknown / Non-Applicable
# 3       Unknown / Non-Applicable
# 4       Unknown / Non-Applicable
# ...                          ...
# 5882    Unknown / Non-Applicable
# 5883    Unknown / Non-Applicable
# 5886  $100 to $500 million (USD)
# 5887    Unknown / Non-Applicable
# 5891  $100 to $500 million (USD)
#
# [5526 rows x 11 columns]

# %%
## Add hourly and employer provided binary columns
df['Hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df['Employer_provided'] = df['Salary Estimate'].apply(lambda x: 1 if 'employer est' in x.lower() else 0)
df['Salary Estimate'].value_counts()
# Out:
# 93-151 (Glassdoor est.)      62
# 113-180 (Glassdoor est.)     61
# 71-122 (Glassdoor est.)      60
# 111-175 (Glassdoor est.)     60
# 119-147 (Glassdoor est.)     44
#                              ..
# 52 - 98 (Glassdoor est.)      1
# 65 - 133 (Glassdoor est.)     1
# 60 - 106 (Glassdoor est.)     1
# 58 - 96 (Glassdoor est.)      1
# 65 - 72 Per Hour              1
# Name: Salary Estimate, Length: 1320, dtype: int64

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# 5882   47 - 89 (Glassdoor est.)     4.2
# 5883  66 - 113 (Glassdoor est.)     4.0
# 5886  67 - 111 (Glassdoor est.)     4.0
# 5887   42 - 76 (Glassdoor est.)     3.6
# 5891           65 - 72 Per Hour     3.7
#
#                                          Company Name        Location  \
# 0                                         Hopper\n3.5    New York, NY
# 1                                        Noom US\n4.5    New York, NY
# 2                                            Decode_M    New York, NY
# 3                               Sapphire Digital\n3.4   Lyndhurst, NJ
# 4                     United Entertainment Group\n3.4    New York, NY
# ...                                               ...             ...
# 5882  Centers for Disease Control and Prevention\n4.2  Cincinnati, OH
# 5883                                     Certara\n4.0  Cincinnati, OH
# 5886                                   New Relic\n4.0  Cincinnati, OH
# 5887                                 Hose Master\n3.6      Euclid, OH
# 5891                                      Epitec\n3.7   Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# 0      501 to 1000 employees    2007  Company - Private
# 1     1001 to 5000 employees    2008  Company - Private
# 2          1 to 50 employees      -1            Unknown
# 3       201 to 500 employees    2019  Company - Private
# 4        51 to 200 employees    2007  Company - Private
# ...                      ...     ...                ...
# 5882        10000+ Employees    1946         Government
# 5883   501 to 1000 Employees    2008   Company - Public
# 5886  1001 to 5000 Employees    2008   Company - Public
# 5887    201 to 500 Employees    1982  Company - Private
# 5891  1001 to 5000 Employees    1978  Company - Private
#
#                                    Industry                     Sector  \
# 0                           Travel Agencies           Travel & Tourism
# 1                 Health, Beauty, & Fitness          Consumer Services
# 2                                        -1                         -1
# 3                                  Internet     Information Technology
# 4                   Advertising & Marketing          Business Services
# ...                                     ...                        ...
# 5882                       Federal Agencies                 Government
# 5883              Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 5886           Computer Hardware & Software     Information Technology
# 5887  Electrical & Electronic Manufacturing              Manufacturing
# 5891                 Staffing & Outsourcing          Business Services
#
#                          Revenue  Hourly  Employer_provided
# 0       Unknown / Non-Applicable       0                  0
# 1       Unknown / Non-Applicable       0                  0
# 2       Unknown / Non-Applicable       0                  0
# 3       Unknown / Non-Applicable       0                  0
# 4       Unknown / Non-Applicable       0                  0
# ...                          ...     ...                ...
# 5882    Unknown / Non-Applicable       0                  0
# 5883    Unknown / Non-Applicable       0                  0
# 5886  $100 to $500 million (USD)       0                  0
# 5887    Unknown / Non-Applicable       0                  0
# 5891  $100 to $500 million (USD)       1                  0
#
# [5526 rows x 13 columns]

# %%
## Add min, max, and average salary columns and cast them into integer type
df['Min_salary'] = df['Salary Estimate'].apply(lambda x: int(x.split('-')[0]))
df['Max_salary'] = df['Salary Estimate'].apply(lambda x: x.split('-')[1])
#df['Max_salary'] = df['Salary Estimate'].apply(lambda x: int(x.split('-')[1]))
#replace anything that is not a number with ''
df['Max_salary'] = df['Salary Estimate'].apply(lambda x: x.split('-')[1]).replace('[^0-9]', '', regex=True)
df['Max_salary'] = df['Max_salary'].apply(int)

#df['Salary Estimate'].apply(lambda x: x.split('-')[1])
# Out:
# 0        181 (Glassdoor est.)
# 1        181 (Glassdoor est.)
# 2        181 (Glassdoor est.)
# 3        181 (Glassdoor est.)
# 4        181 (Glassdoor est.)
#                 ...
# 5882      89 (Glassdoor est.)
# 5883     113 (Glassdoor est.)
# 5886     111 (Glassdoor est.)
# 5887      76 (Glassdoor est.)
# 5891              72 Per Hour
# Name: Salary Estimate, Length: 5526, dtype: object

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# 5882   47 - 89 (Glassdoor est.)     4.2
# 5883  66 - 113 (Glassdoor est.)     4.0
# 5886  67 - 111 (Glassdoor est.)     4.0
# 5887   42 - 76 (Glassdoor est.)     3.6
# 5891           65 - 72 Per Hour     3.7
#
#                                          Company Name        Location  \
# 0                                         Hopper\n3.5    New York, NY
# 1                                        Noom US\n4.5    New York, NY
# 2                                            Decode_M    New York, NY
# 3                               Sapphire Digital\n3.4   Lyndhurst, NJ
# 4                     United Entertainment Group\n3.4    New York, NY
# ...                                               ...             ...
# 5882  Centers for Disease Control and Prevention\n4.2  Cincinnati, OH
# 5883                                     Certara\n4.0  Cincinnati, OH
# 5886                                   New Relic\n4.0  Cincinnati, OH
# 5887                                 Hose Master\n3.6      Euclid, OH
# 5891                                      Epitec\n3.7   Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# 0      501 to 1000 employees    2007  Company - Private
# 1     1001 to 5000 employees    2008  Company - Private
# 2          1 to 50 employees      -1            Unknown
# 3       201 to 500 employees    2019  Company - Private
# 4        51 to 200 employees    2007  Company - Private
# ...                      ...     ...                ...
# 5882        10000+ Employees    1946         Government
# 5883   501 to 1000 Employees    2008   Company - Public
# 5886  1001 to 5000 Employees    2008   Company - Public
# 5887    201 to 500 Employees    1982  Company - Private
# 5891  1001 to 5000 Employees    1978  Company - Private
#
#                                    Industry                     Sector  \
# 0                           Travel Agencies           Travel & Tourism
# 1                 Health, Beauty, & Fitness          Consumer Services
# 2                                        -1                         -1
# 3                                  Internet     Information Technology
# 4                   Advertising & Marketing          Business Services
# ...                                     ...                        ...
# 5882                       Federal Agencies                 Government
# 5883              Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 5886           Computer Hardware & Software     Information Technology
# 5887  Electrical & Electronic Manufacturing              Manufacturing
# 5891                 Staffing & Outsourcing          Business Services
#
#                          Revenue  Hourly  Employer_provided  Min_salary  \
# 0       Unknown / Non-Applicable       0                  0         111
# 1       Unknown / Non-Applicable       0                  0         111
# 2       Unknown / Non-Applicable       0                  0         111
# 3       Unknown / Non-Applicable       0                  0         111
# 4       Unknown / Non-Applicable       0                  0         111
# ...                          ...     ...                ...         ...
# 5882    Unknown / Non-Applicable       0                  0          47
# 5883    Unknown / Non-Applicable       0                  0          66
# 5886  $100 to $500 million (USD)       0                  0          67
# 5887    Unknown / Non-Applicable       0                  0          42
# 5891  $100 to $500 million (USD)       1                  0          65
#
#       Max_salary
# 0            181
# 1            181
# 2            181
# 3            181
# 4            181
# ...          ...
# 5882          89
# 5883         113
# 5886         111
# 5887          76
# 5891          72
#
# [5526 rows x 15 columns]

# %%
# Convert hourly wages to annual
df['Min_salary'] = df.apply(lambda x: x.Min_salary if x.Hourly == 0 else x.Min_salary*2.05, axis=1)
df['Max_salary'] = df.apply(lambda x: x.Max_salary if x.Hourly == 0 else x.Max_salary*2.05, axis=1)

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# 5882   47 - 89 (Glassdoor est.)     4.2
# 5883  66 - 113 (Glassdoor est.)     4.0
# 5886  67 - 111 (Glassdoor est.)     4.0
# 5887   42 - 76 (Glassdoor est.)     3.6
# 5891           65 - 72 Per Hour     3.7
#
#                                          Company Name        Location  \
# 0                                         Hopper\n3.5    New York, NY
# 1                                        Noom US\n4.5    New York, NY
# 2                                            Decode_M    New York, NY
# 3                               Sapphire Digital\n3.4   Lyndhurst, NJ
# 4                     United Entertainment Group\n3.4    New York, NY
# ...                                               ...             ...
# 5882  Centers for Disease Control and Prevention\n4.2  Cincinnati, OH
# 5883                                     Certara\n4.0  Cincinnati, OH
# 5886                                   New Relic\n4.0  Cincinnati, OH
# 5887                                 Hose Master\n3.6      Euclid, OH
# 5891                                      Epitec\n3.7   Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# 0      501 to 1000 employees    2007  Company - Private
# 1     1001 to 5000 employees    2008  Company - Private
# 2          1 to 50 employees      -1            Unknown
# 3       201 to 500 employees    2019  Company - Private
# 4        51 to 200 employees    2007  Company - Private
# ...                      ...     ...                ...
# 5882        10000+ Employees    1946         Government
# 5883   501 to 1000 Employees    2008   Company - Public
# 5886  1001 to 5000 Employees    2008   Company - Public
# 5887    201 to 500 Employees    1982  Company - Private
# 5891  1001 to 5000 Employees    1978  Company - Private
#
#                                    Industry                     Sector  \
# 0                           Travel Agencies           Travel & Tourism
# 1                 Health, Beauty, & Fitness          Consumer Services
# 2                                        -1                         -1
# 3                                  Internet     Information Technology
# 4                   Advertising & Marketing          Business Services
# ...                                     ...                        ...
# 5882                       Federal Agencies                 Government
# 5883              Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 5886           Computer Hardware & Software     Information Technology
# 5887  Electrical & Electronic Manufacturing              Manufacturing
# 5891                 Staffing & Outsourcing          Business Services
#
#                          Revenue  Hourly  Employer_provided  Min_salary  \
# 0       Unknown / Non-Applicable       0                  0      111.00
# 1       Unknown / Non-Applicable       0                  0      111.00
# 2       Unknown / Non-Applicable       0                  0      111.00
# 3       Unknown / Non-Applicable       0                  0      111.00
# 4       Unknown / Non-Applicable       0                  0      111.00
# ...                          ...     ...                ...         ...
# 5882    Unknown / Non-Applicable       0                  0       47.00
# 5883    Unknown / Non-Applicable       0                  0       66.00
# 5886  $100 to $500 million (USD)       0                  0       67.00
# 5887    Unknown / Non-Applicable       0                  0       42.00
# 5891  $100 to $500 million (USD)       1                  0      133.25
#
#       Max_salary
# 0          181.0
# 1          181.0
# 2          181.0
# 3          181.0
# 4          181.0
# ...          ...
# 5882        89.0
# 5883       113.0
# 5886       111.0
# 5887        76.0
# 5891       147.6
#
# [5526 rows x 15 columns]

# %%
df['Average_salary'] = (df.Min_salary + df.Max_salary)/2
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# 5882   47 - 89 (Glassdoor est.)     4.2
# 5883  66 - 113 (Glassdoor est.)     4.0
# 5886  67 - 111 (Glassdoor est.)     4.0
# 5887   42 - 76 (Glassdoor est.)     3.6
# 5891           65 - 72 Per Hour     3.7
#
#                                          Company Name        Location  \
# 0                                         Hopper\n3.5    New York, NY
# 1                                        Noom US\n4.5    New York, NY
# 2                                            Decode_M    New York, NY
# 3                               Sapphire Digital\n3.4   Lyndhurst, NJ
# 4                     United Entertainment Group\n3.4    New York, NY
# ...                                               ...             ...
# 5882  Centers for Disease Control and Prevention\n4.2  Cincinnati, OH
# 5883                                     Certara\n4.0  Cincinnati, OH
# 5886                                   New Relic\n4.0  Cincinnati, OH
# 5887                                 Hose Master\n3.6      Euclid, OH
# 5891                                      Epitec\n3.7   Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# 0      501 to 1000 employees    2007  Company - Private
# 1     1001 to 5000 employees    2008  Company - Private
# 2          1 to 50 employees      -1            Unknown
# 3       201 to 500 employees    2019  Company - Private
# 4        51 to 200 employees    2007  Company - Private
# ...                      ...     ...                ...
# 5882        10000+ Employees    1946         Government
# 5883   501 to 1000 Employees    2008   Company - Public
# 5886  1001 to 5000 Employees    2008   Company - Public
# 5887    201 to 500 Employees    1982  Company - Private
# 5891  1001 to 5000 Employees    1978  Company - Private
#
#                                    Industry                     Sector  \
# 0                           Travel Agencies           Travel & Tourism
# 1                 Health, Beauty, & Fitness          Consumer Services
# 2                                        -1                         -1
# 3                                  Internet     Information Technology
# 4                   Advertising & Marketing          Business Services
# ...                                     ...                        ...
# 5882                       Federal Agencies                 Government
# 5883              Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 5886           Computer Hardware & Software     Information Technology
# 5887  Electrical & Electronic Manufacturing              Manufacturing
# 5891                 Staffing & Outsourcing          Business Services
#
#                          Revenue  Hourly  Employer_provided  Min_salary  \
# 0       Unknown / Non-Applicable       0                  0      111.00
# 1       Unknown / Non-Applicable       0                  0      111.00
# 2       Unknown / Non-Applicable       0                  0      111.00
# 3       Unknown / Non-Applicable       0                  0      111.00
# 4       Unknown / Non-Applicable       0                  0      111.00
# ...                          ...     ...                ...         ...
# 5882    Unknown / Non-Applicable       0                  0       47.00
# 5883    Unknown / Non-Applicable       0                  0       66.00
# 5886  $100 to $500 million (USD)       0                  0       67.00
# 5887    Unknown / Non-Applicable       0                  0       42.00
# 5891  $100 to $500 million (USD)       1                  0      133.25
#
#       Max_salary  Average_salary
# 0          181.0         146.000
# 1          181.0         146.000
# 2          181.0         146.000
# 3          181.0         146.000
# 4          181.0         146.000
# ...          ...             ...
# 5882        89.0          68.000
# 5883       113.0          89.500
# 5886       111.0          89.000
# 5887        76.0          59.000
# 5891       147.6         140.425
#
# [5526 rows x 16 columns]

# %%
## Ensure ratings are float type
df['Rating'] = df['Rating'].apply(lambda x: float(x))

# %%
## Remove rating from the end of company names
df['Company Name'] = df['Company Name'].apply(lambda x: x.split('\n')[0])

# %%
#what state is the job in

df['State'] = df['Location'].apply(lambda x: x.split()[-1])
df = df[df.State != 'Kingdom'] # remove United Kingdom
df = df[df.State != 'States'] # remove United States

# %%
# Replace non-numeric cells in Founded column with -1
df['Founded'].replace('[^0-9]', -1, regex=True, inplace=True)

df['Company_age'] = df['Founded'].apply(lambda x: 2024-int(x) if int(x)>0 else -1)

# %%
df
# Out:
#                                               Job Title  Rating  \
# 0                                 Senior Data Scientist     3.5
# 1                     Data Scientist, Product Analytics     4.5
# 2                                  Data Science Manager    -1.0
# 3                                          Data Analyst     3.4
# 4                                Director, Data Science     3.4
# ...                                                 ...     ...
# 5882              Supervisory Research Health Scientist     4.2
# 5883                  Senior SAS Programmer (Scientist)     4.0
# 5886  Senior Data Analyst - Product Analytics (open ...     4.0
# 5887                Manufacturing Data Analyst Engineer     3.6
# 5891               Data Scientist/ Full Stack Developer     3.7
#
#                                     Company Name        Location  \
# 0                                         Hopper    New York, NY
# 1                                        Noom US    New York, NY
# 2                                       Decode_M    New York, NY
# 3                               Sapphire Digital   Lyndhurst, NJ
# 4                     United Entertainment Group    New York, NY
# ...                                          ...             ...
# 5882  Centers for Disease Control and Prevention  Cincinnati, OH
# 5883                                     Certara  Cincinnati, OH
# 5886                                   New Relic  Cincinnati, OH
# 5887                                 Hose Master      Euclid, OH
# 5891                                      Epitec   Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# 0      501 to 1000 employees    2007  Company - Private
# 1     1001 to 5000 employees    2008  Company - Private
# 2          1 to 50 employees      -1            Unknown
# 3       201 to 500 employees    2019  Company - Private
# 4        51 to 200 employees    2007  Company - Private
# ...                      ...     ...                ...
# 5882        10000+ Employees    1946         Government
# 5883   501 to 1000 Employees    2008   Company - Public
# 5886  1001 to 5000 Employees    2008   Company - Public
# 5887    201 to 500 Employees    1982  Company - Private
# 5891  1001 to 5000 Employees    1978  Company - Private
#
#                                    Industry                     Sector  \
# 0                           Travel Agencies           Travel & Tourism
# 1                 Health, Beauty, & Fitness          Consumer Services
# 2                                        -1                         -1
# 3                                  Internet     Information Technology
# 4                   Advertising & Marketing          Business Services
# ...                                     ...                        ...
# 5882                       Federal Agencies                 Government
# 5883              Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 5886           Computer Hardware & Software     Information Technology
# 5887  Electrical & Electronic Manufacturing              Manufacturing
# 5891                 Staffing & Outsourcing          Business Services
#
#                          Revenue  Hourly  Employer_provided  Min_salary  \
# 0       Unknown / Non-Applicable       0                  0      111.00
# 1       Unknown / Non-Applicable       0                  0      111.00
# 2       Unknown / Non-Applicable       0                  0      111.00
# 3       Unknown / Non-Applicable       0                  0      111.00
# 4       Unknown / Non-Applicable       0                  0      111.00
# ...                          ...     ...                ...         ...
# 5882    Unknown / Non-Applicable       0                  0       47.00
# 5883    Unknown / Non-Applicable       0                  0       66.00
# 5886  $100 to $500 million (USD)       0                  0       67.00
# 5887    Unknown / Non-Applicable       0                  0       42.00
# 5891  $100 to $500 million (USD)       1                  0      133.25
#
#       Max_salary  Average_salary State  Company_age
# 0          181.0         146.000    NY           17
# 1          181.0         146.000    NY           16
# 2          181.0         146.000    NY           -1
# 3          181.0         146.000    NJ            5
# 4          181.0         146.000    NY           17
# ...          ...             ...   ...          ...
# 5882        89.0          68.000    OH           78
# 5883       113.0          89.500    OH           16
# 5886       111.0          89.000    OH           16
# 5887        76.0          59.000    OH           42
# 5891       147.6         140.425    WI           46
#
# [5522 rows x 17 columns]

# %%
# Organize job titles

def title_organizer(x):
    x = x.lower()
    if ('data scientist' in x) or ('data science' in x) :
        return 'data scientist'
    elif 'data engineer' in x:
        return 'data engineer'
    elif 'deep learning' in x:
        return 'deep learning engineer'
    elif 'machine learning' in x:
        return 'machine learning engineer'
    elif 'director' in x:
        return 'director'
    elif 'manager' in x:
        return 'manager'
    elif 'analyst' in x:
        return 'analyst'
    elif 'researcher' in x:
        return 'researcher'
    else:
        return 'other'
df['Title'] = df['Job Title'].apply(title_organizer)

# %%
# Senior position

def senior_junior(x):
    x = x.lower()
    if 'sr' in x or 'senior' in x or 'sr.' in x or 'lead' in x or 'principal' in x or 'vp' in x or 'manager' in x:
        return 'senior'
    elif 'jr' in x or 'junior' in x or 'jr.' in x:
        return 'junior'
    else:
        return 'other'
df['Seniority'] = df['Job Title'].apply(senior_junior)

# %%
# Size

df['Size'].replace('Unknown', '-1', regex=True, inplace=True)
df['Size'] = df['Size'].str.lower()

# %%
df.drop(['Company Name', 'Location', 'Founded', 'Job Title',
         'Revenue', 'Min_salary', 'Max_salary'], inplace=True,
        axis=1)

# %%
df = df.reindex(columns=['Average_salary', 'Title','Seniority',
                         'Rating', 'Hourly', 'Employer_provided',
                         'Company_age',
                         'Industry', 'Sector', 'Type of ownership',
                         'Size', 'State'])

# %%
df
# Out:
#       Average_salary           Title Seniority  Rating  Hourly  \
# 0            146.000  data scientist    senior     3.5       0
# 1            146.000  data scientist     other     4.5       0
# 2            146.000  data scientist    senior    -1.0       0
# 3            146.000         analyst     other     3.4       0
# 4            146.000  data scientist     other     3.4       0
# ...              ...             ...       ...     ...     ...
# 5882          68.000           other     other     4.2       0
# 5883          89.500           other    senior     4.0       0
# 5886          89.000         analyst    senior     4.0       0
# 5887          59.000         analyst     other     3.6       0
# 5891         140.425  data scientist     other     3.7       1
#
#       Employer_provided  Company_age                               Industry  \
# 0                     0           17                        Travel Agencies
# 1                     0           16              Health, Beauty, & Fitness
# 2                     0           -1                                     -1
# 3                     0            5                               Internet
# 4                     0           17                Advertising & Marketing
# ...                 ...          ...                                    ...
# 5882                  0           78                       Federal Agencies
# 5883                  0           16              Biotech & Pharmaceuticals
# 5886                  0           16           Computer Hardware & Software
# 5887                  0           42  Electrical & Electronic Manufacturing
# 5891                  0           46                 Staffing & Outsourcing
#
#                          Sector  Type of ownership                    Size  \
# 0              Travel & Tourism  Company - Private   501 to 1000 employees
# 1             Consumer Services  Company - Private  1001 to 5000 employees
# 2                            -1            Unknown       1 to 50 employees
# 3        Information Technology  Company - Private    201 to 500 employees
# 4             Business Services  Company - Private     51 to 200 employees
# ...                         ...                ...                     ...
# 5882                 Government         Government        10000+ employees
# 5883  Biotech & Pharmaceuticals   Company - Public   501 to 1000 employees
# 5886     Information Technology   Company - Public  1001 to 5000 employees
# 5887              Manufacturing  Company - Private    201 to 500 employees
# 5891          Business Services  Company - Private  1001 to 5000 employees
#
#      State
# 0       NY
# 1       NY
# 2       NY
# 3       NJ
# 4       NY
# ...    ...
# 5882    OH
# 5883    OH
# 5886    OH
# 5887    OH
# 5891    WI
#
# [5522 rows x 12 columns]

# %%
df['Average_salary'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Average_salary'].plot.hist(bins=5, color='red', edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
state = df['State'].value_counts()

# %%
state.plot(kind= 'bar',color = 'yellow')
# Out:
# <AxesSubplot:>
